# %%
import numpy as np
import seaborn as sns
import pandas as pd
from matplotlib import pyplot as plt
from fun import *
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
a = np.array([41,12])
b = np.array([88,12,33,0])

# %%
historic = SignalsStory(np.array([4,55,20,11,111,1]))
# Out:
# Events : 6 | First : 1 | Last : 111 | Amplitude : 110

# %%
historic.Data_Adder(a)
# Out:
# Events : 8 | First : 1 | Last : 111 | Amplitude : 110

# %%
historic.Data_Filter(interval = ["1970-01-01 00:00:11","1970-01-01 00:00:55"])
# Out:
# interval seen as a list of two YYYY-MM-DD HH:MM:SS timestamps format
# DATA_FILTERED attribut has been created

# %%
historic.See(dims=(20,3))

# %%
historic.See(filter_boolean = True)
